# %%
from bs4 import BeautifulSoup as bs
from requests import get

# %%
#the metacritic data seemed to be prevented from getting scraped for some reason so I used a different website
url = "https://consequenceofsound.net/upcoming-releases/"

# %%
response = get(url)
#print(response.text[:500])

# %%
html_soup = bs(response.text, 'html.parser')

# %%
#<p style="padding-left:30px;">
html_albums = html_soup.find_all('p', style="padding-left:30px;")

# %%
html_albums[0].strong
# Out:
# <strong>Anna-Marie</strong>

# %%
albums=[]

for a in html_albums:
    print(a)


'''
for a in html_albums:
    artist = a.strong.text
    alb = a.em.text
    #I'm not really sure what's wrong but for some reason wben I try to run this section I get an error saying that 
    #NoneType object has no attribute text, but it works fine for the first line and when I print the album name
    #or the type of the album name it seems fine. But other than that it should work.
    #print(alb)
    #print(type(alb))
    albums.append((artist, alb))
'''
#print(albums)
# Out:
# <p style="padding-left:30px;">— <strong>Anna-Marie</strong> – <em>Speak Your Mind</em></p>
# <p style="padding-left:30px;">— <strong>Anthrax</strong> – <em>Kings Among Scotland</em></p>
# <p style="padding-left:30px;">— <strong>The Armed</strong> – <em>Only Love</em></p>
# <p style="padding-left:30px;">— <strong>Bart Davenport</strong> – <em>Blue Motel</em></p>
# <p style="padding-left:30px;">— <strong>The Beat Escape</strong> – <em>Life Is Short The Answer’s Long</em></p>
# <p style="padding-left:30px;">— <strong>Beth Nielsen Chapman</strong> – <em>Hearts of Glass</em></p>
# <p style="padding-left:30px;">— <strong>Blossoms</strong> – <em>Cool Like You</em></p>
# <p style="padding-left:30px;">— <strong>Bossie</strong> – <em>Not Pictured</em></p>
# <p style="padding-left:30px;">— <strong>DMA’s</strong> – <a href="https://consequenceofsound.net/2018/02/dmas-announce-new-album-for-now-share-in-the-air-video-watch/" rel="noopener" target="_blank"><em>For Now</em></a></p>
# ...
