# %%
#Import necessary modules inlcuded Tensorflow
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
#Read in File
data = pd.read_csv("balanced_pop_unpop_features.csv")

# %%
#Remove track name column
del data["Unnamed: 0"]

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0       0.21400         0.666       178242   0.677          0.000000    2
# 1       0.01340         0.807       183750   0.916          0.000012    0
# 2       0.00162         0.791       279507   0.615          0.000065    6
# 3       0.76300         0.707       275227   0.709          0.000000   11
# 4       0.57000         0.629       250173   0.572          0.000000    5
#
#    liveness  loudness  speechiness    tempo  time_signature  valence  label
# 0    0.0979    -5.743       0.0326  100.014               4    0.178      1
# 1    0.0787    -3.282       0.2260  127.973               4    0.651      1
# 2    0.0812    -6.149       0.0667  128.017               4    0.393      1
# 3    0.2740    -3.979       0.3400   89.094               4    0.501      1
# 4    0.1920    -7.733       0.0387  100.015               4    0.386      1

# %%
#Shuffle dataset
for i in range(10): data = data.sample(frac=1)

# %%
data.head()
# Out:
#      acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 967        0.0617         0.594       205200   0.824               0.0    9
# 231        0.0539         0.562       236865   0.878               0.0    8
# 245        0.0115         0.527       241307   0.942               0.0    1
# 5          0.2260         0.718       222200   0.801               0.0    0
# 186        0.0110         0.487       214320   0.876               0.0    0
#
#      liveness  loudness  speechiness    tempo  time_signature  valence  label
# 967    0.0861    -4.252       0.0458  116.005               4    0.671      0
# 231    0.1120    -4.806       0.0387  103.029               4    0.558      1
# 245    0.1880    -5.640       0.0366  148.723               4    0.495      1
# 5      0.3900    -2.581       0.0386  127.016               4    0.538      1
# 186    0.4010    -3.152       0.0946  164.997               4    0.725      1

# %%
#About a 70-30 split between training and testing 
train = data.iloc[:750]
test = data.iloc[750:]

# %%
train.head()
# Out:
#      acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 967        0.0617         0.594       205200   0.824               0.0    9
# 231        0.0539         0.562       236865   0.878               0.0    8
# 245        0.0115         0.527       241307   0.942               0.0    1
# 5          0.2260         0.718       222200   0.801               0.0    0
# 186        0.0110         0.487       214320   0.876               0.0    0
#
#      liveness  loudness  speechiness    tempo  time_signature  valence  label
# 967    0.0861    -4.252       0.0458  116.005               4    0.671      0
# 231    0.1120    -4.806       0.0387  103.029               4    0.558      1
# 245    0.1880    -5.640       0.0366  148.723               4    0.495      1
# 5      0.3900    -2.581       0.0386  127.016               4    0.538      1
# 186    0.4010    -3.152       0.0946  164.997               4    0.725      1

# %%
print(train.shape,test.shape)
# Out:
# (750, 13) (322, 13)

# %%
#Split entries in train_x: features and train_y: labels
train_x = train.iloc[:,:12]
train_y = train.iloc[:,12:].astype(int)

test_x = test.iloc[:,:12]
test_y = test.iloc[:,12:].astype(int)

#Take Z-score
train_x = (train_x-train_x.mean())/(train_x.std())
test_x = (test_x-test_x.mean())/(test_x.std())

# %%
train_x.head()
# Out:
#      acousticness  danceability  duration_ms    energy  instrumentalness  \
# 967     -0.504949     -0.360200    -0.413106  0.850043         -0.112526
# 231     -0.543768     -0.586605     0.359633  1.174642         -0.112526
# 245     -0.754784     -0.834235     0.468033  1.559353         -0.112526
# 5        0.312739      0.517118     0.001755  0.711788         -0.112526
# 186     -0.757272     -1.117241    -0.190545  1.162620         -0.112526
#
#           key  liveness  loudness  speechiness     tempo  time_signature  \
# 967  0.929576 -0.660979  0.681207    -0.542359 -0.209971        0.110493
# 231  0.661841 -0.484162  0.453723    -0.612502 -0.673268        0.110493
# 245 -1.212305  0.034683  0.111266    -0.633249  0.958197        0.110493
# 5   -1.480040  1.413719  1.367354    -0.613490  0.183167        0.110493
# 186 -1.480040  1.488815  1.132889    -0.060247  1.539246        0.110493
#
#       valence
# 967  0.718048
# 231  0.214407
# 245 -0.066383
# 5    0.125268
# 186  0.958725

# %%
#Create feature column for net 
feature_columns = []
for i in train_x.columns:
    feature_columns.append(tf.feature_column.numeric_column(key=i))

# %%
#Lil preview 
for i in feature_columns:
    print(i)
    print("")
# Out:
# _NumericColumn(key='acousticness', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='danceability', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='duration_ms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='energy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='instrumentalness', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='key', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='liveness', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='loudness', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='speechiness', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='tempo', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='time_signature', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
#
# _NumericColumn(key='valence', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)

# %%
#Make estimator/ Model
classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns
                                        , hidden_units=[5],
                                        n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/81/_01kvw1s7xj6hjfw2y34w9_40000gn/T/tmp5x5f24fj
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/81/_01kvw1s7xj6hjfw2y34w9_40000gn/T/tmp5x5f24fj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11e8ce2e8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
def train_input_fn(features, labels, batch_size):
    """An input function for training"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)

    # Return the dataset.
    return dataset

# %%
# Train the Model.
classifier.train(
    input_fn=lambda:train_input_fn(train_x, train_y,300),
    steps=10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/81/_01kvw1s7xj6hjfw2y34w9_40000gn/T/tmp5x5f24fj/model.ckpt.
# INFO:tensorflow:loss = 233.94113, step = 1
# INFO:tensorflow:global_step/sec: 220.717
# INFO:tensorflow:loss = 196.8521, step = 101 (0.454 sec)
# INFO:tensorflow:global_step/sec: 292.479
# INFO:tensorflow:loss = 196.14568, step = 201 (0.342 sec)
# INFO:tensorflow:global_step/sec: 280.619
# INFO:tensorflow:loss = 194.33151, step = 301 (0.356 sec)
# INFO:tensorflow:global_step/sec: 289.686
# INFO:tensorflow:loss = 191.58162, step = 401 (0.345 sec)
# INFO:tensorflow:global_step/sec: 291.888
# INFO:tensorflow:loss = 196.0069, step = 501 (0.343 sec)
# INFO:tensorflow:global_step/sec: 297.36
# INFO:tensorflow:loss = 194.29211, step = 601 (0.336 sec)
# INFO:tensorflow:global_step/sec: 295.64
# INFO:tensorflow:loss = 188.25626, step = 701 (0.338 sec)
# INFO:tensorflow:global_step/sec: 289.296
# INFO:tensorflow:loss = 196.41476, step = 801 (0.346 sec)
# INFO:tensorflow:global_step/sec: 292.432
# INFO:tensorflow:loss = 190.44019, step = 901 (0.342 sec)
# INFO:tensorflow:global_step/sec: 292.24

# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-10-21:23:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/81/_01kvw1s7xj6hjfw2y34w9_40000gn/T/tmp5x5f24fj/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-10-21:23:18
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.55279505, accuracy_baseline = 0.5124223, auc = 0.5702374, auc_precision_recall = 0.57726234, average_loss = 0.7435979, global_step = 10000, label/mean = 0.48757765, loss = 239.43852, precision = 0.54140127, prediction/mean = 0.50439, recall = 0.54140127

# %%
eval_result
# Out:
# {'accuracy': 0.55279505,
#  'accuracy_baseline': 0.5124223,
#  'auc': 0.5702374,
#  'auc_precision_recall': 0.57726234,
#  'average_loss': 0.7435979,
#  'global_step': 10000,
#  'label/mean': 0.48757765,
#  'loss': 239.43852,
#  'precision': 0.54140127,
#  'prediction/mean': 0.50439,
#  'recall': 0.54140127}

# %%
test_x.head()
# Out:
#      acousticness  danceability  duration_ms    energy  instrumentalness  \
# 83      -0.687096      0.359535     0.605542  1.312766         -0.110267
# 430      0.049392     -0.477904    -0.377002  1.009337         -0.110267
# 684     -0.258450      1.196973     0.064255  0.630052         -0.108660
# 597     -0.741668      0.087933    -0.923926  0.075712         -0.110267
# 111     -0.566291      0.917827    -1.428319 -0.251057         -0.110267
#
#           key  liveness  loudness  speechiness     tempo  time_signature  \
# 83   1.085946 -0.579159  0.273568    -0.238844  0.066716        0.109938
# 430 -0.599233 -0.625257  0.883221    -0.112231  1.652533        0.109938
# 684  0.243357  0.526448  0.097019    -0.291400 -0.555647        0.109938
# 597  0.805083 -0.712992  0.026400    -0.735740 -0.487491        0.109938
# 111 -1.441823  0.489272 -1.306434    -0.635405 -0.763124        0.109938
#
#       valence
# 83   0.008967
# 430  1.888484
# 684  0.245647
# 597  2.111241
# 111  0.737570

# %%
#Look at results of net preidctions compared to actual label
test_x_np = test_x.values.transpose()


predict_input_fn = tf.estimator.inputs.numpy_input_fn(
    x=dict(test_x),
    num_epochs=1,
    shuffle=False)

predictions = list(classifier.predict(input_fn=predict_input_fn))
predicted_classes = [p["classes"] for p in predictions]

for i,j in zip(predicted_classes,test_y.label):
    print(i,j)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/81/_01kvw1s7xj6hjfw2y34w9_40000gn/T/tmp5x5f24fj/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [b'1'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'1'] 0
# [b'0'] 0
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'1'] 0
# [b'0'] 0
# [b'0'] 1
# [b'1'] 0
# [b'1'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'1'] 1
# [b'1'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'1'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'1'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'1'] 1
# [b'0'] 0
# [b'1'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'1'] 0
# [b'0'] 1
# [b'1'] 1
# [b'1'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'1'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'1'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'1'] 0
# [b'0'] 1
# [b'0'] 1
# [b'1'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'1'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'1'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'1'] 1
# [b'1'] 1
# [b'0'] 0
# [b'1'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'1'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'1'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'1'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'1'] 1
# [b'0'] 0
# [b'0'] 0
# [b'1'] 0
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'1'] 1
# [b'1'] 1
# [b'0'] 1
# [b'0'] 1
# [b'1'] 1
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'1'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'1'] 1
# [b'0'] 0
# [b'1'] 1
# [b'1'] 0
# [b'0'] 1
# [b'1'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'1'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'1'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'1'] 0
# [b'1'] 0
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'1'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 1
# [b'0'] 0
# [b'0'] 0
# [b'0'] 0
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py:696: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
