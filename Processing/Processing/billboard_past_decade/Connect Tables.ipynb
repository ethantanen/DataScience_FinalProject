# %%
import pandas as pd

# %%
d1 = pd.read_csv("billboard_hot_100_features.csv",index_col=0).transpose()
d2 = pd.read_csv("billboard_top_100_past_decade_features_5.csv",index_col=0)

# %%
d2.shape
# Out:
# (5, 40)

# %%
col = []
for i in d1.columns:
    col.append(i)

# %%
for i in range(len(col)):
    print(i,col[i])
# Out:
# 0 1958-10-08
# 1 1958-12-22
# 2 1959-03-07
# 3 1959-05-21
# 4 1959-08-04
# 5 1959-10-18
# 6 1960-01-01
# 7 1960-03-16
# 8 1960-05-30
# 9 1960-08-13
# 10 1960-10-27
# 11 1961-01-11
# 12 1961-03-27
# 13 1961-06-10
# 14 1961-08-24
# 15 1961-11-07
# 16 1962-01-21
# 17 1962-04-06
# 18 1962-06-20
# 19 1962-09-03
# 20 1962-11-17
# 21 1963-01-31
# 22 1963-04-16
# 23 1963-06-30
# 24 1963-09-13
# 25 1963-11-27
# 26 1964-02-10
# 27 1964-04-25
# 28 1964-07-09
# 29 1964-09-22
# 30 1964-12-06
# 31 1965-02-20
# 32 1965-05-06
# 33 1965-07-20
# 34 1965-10-03
# 35 1965-12-17
# 36 1966-03-02
# 37 1966-05-16
# 38 1966-07-30
# 39 1966-10-13
# 40 1966-12-27
# 41 1967-03-12
# 42 1967-05-26
# 43 1967-08-09
# 44 1967-10-23
# 45 1968-01-06
# 46 1968-03-21
# 47 1968-06-04
# 48 1968-08-18
# 49 1968-11-01
# 50 1969-01-16
# 51 1969-04-01
# 52 1969-06-15
# 53 1969-08-29
# 54 1969-11-12
# 55 1970-01-26
# 56 1970-04-11
# 57 1970-06-25
# 58 1970-09-08
# 59 1970-11-22
# 60 1971-02-05
# 61 1971-04-21
# 62 1971-12-02
# ...

# %%
col = col[:]

# %%
d3 = d1[col]

# %%
df = d3
df[d2.columns]=d2

# %%
df.shape
# Out:
# (5, 321)

# %%
df.transpose().danceability.plot()
