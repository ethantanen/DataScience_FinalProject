# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(index=list(range(1,101)))

# %%
os.chdir("Data")

for filename in glob.glob("*.csv"):
    f = pd.read_csv(filename)
    df[f.columns]= f

# %%
del df['Unnamed: 0']

# %%
df.shape
# Out:
# (100, 4380)

# %% [markdown]
# This chart is of the top 100 songs for each date. I want to average features for each date; so, a chart where the columns are dates and the rows average of features

# %%
df.head()
# Out:
#                                           1958-01-01  \
# 1                        Splish Splash , Bobby Darin
# 2  Hard Headed Woman , Elvis Presley With The Jor...
# 3                                 When , Kalin Twins
# 4  Rebel-'rouser , Duane Eddy His Twangy Guitar A...
# 5                          Yakety Yak , The Coasters
#
#                                           1958-01-06  \
# 1                        Splish Splash , Bobby Darin
# 2  Hard Headed Woman , Elvis Presley With The Jor...
# 3                                 When , Kalin Twins
# 4  Rebel-'rouser , Duane Eddy His Twangy Guitar A...
# 5                          Yakety Yak , The Coasters
#
#                                           1958-01-11  \
# 1                        Splish Splash , Bobby Darin
# 2  Hard Headed Woman , Elvis Presley With The Jor...
# 3                                 When , Kalin Twins
# 4  Rebel-'rouser , Duane Eddy His Twangy Guitar A...
# ...

# %%
df.to_csv("top_100_by_years.csv")
